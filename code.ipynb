# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import LoraConfig, get_peft_model, TaskType, prepare_model_for_kbit_training
from trl import SFTTrainer, SFTConfig
import matplotlib.pyplot as plt



# On forcel'utilisation de bf16
os.environ["ACCELERATE_MIXED_PRECISION"] = "bf16"
os.environ["TORCH_DTYPE"] = "bfloat16"



# On utilise le chemin du drive que nous avons monté
PATH_PROJET = "/content/drive/MyDrive/projet_cv/projet-cv"
DOSSIER_CACHE = os.path.join(PATH_PROJET, "cache")
DATA_PATH = os.path.join(PATH_PROJET, "data/dataset.jsonl")
OUT_DIR = os.path.join(PATH_PROJET, "model/cv-lora")

MODEL_ID = "microsoft/phi-3-mini-4k-instruct"
# On met False car Colab doit télécharger le modèle la première fois
LOCAL_FILES_ONLY = True

def main():
    os.makedirs(OUT_DIR, exist_ok=True)
    os.makedirs(DOSSIER_CACHE, exist_ok=True)

    # 1) Dataset
    # Chargement du dataset et dicision du data set en dataset d'entrainement et datset d'évaluation
    full_dataset = load_dataset("json", data_files=DATA_PATH)["train"]
    split_ds = full_dataset.train_test_split(test_size=0.2, seed=42) # 20% pour l'evaluation
    train_ds = split_ds["train"]
    eval_ds = split_ds["test"]

    # 2) Tokenizer
    tokenizer = AutoTokenizer.from_pretrained(
        MODEL_ID,
        cache_dir=DOSSIER_CACHE,
        use_fast=True,
        trust_remote_code=True, # Requis pour Phi-3
        local_files_only=LOCAL_FILES_ONLY,
    )
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    # 3) QLoRA 4-bit (Optimisé pour le GPU T4 de Colab)
    bnb_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_use_double_quant=True,
    )

    # 4) Base model
    model = AutoModelForCausalLM.from_pretrained(
        MODEL_ID,
        device_map="auto",
        cache_dir=DOSSIER_CACHE,
        quantization_config=bnb_config,
        trust_remote_code=True, # Requis pour Phi-3
        torch_dtype=torch.float16,
        local_files_only=LOCAL_FILES_ONLY,
    )

    # 5) Préparation k-bit
    model = prepare_model_for_kbit_training(model)

    # 6) LoRA
    lora_config = LoraConfig(
        r=32,
        lora_alpha=64,
        lora_dropout=0.05,
        target_modules="all-linear",
        bias="none",
        task_type=TaskType.CAUSAL_LM,
    )
    model = get_peft_model(model, lora_config)
    model.print_trainable_parameters()

    # 7) Config TRL
    sft_args = SFTConfig(
        output_dir=OUT_DIR,
        num_train_epochs=4,
        per_device_train_batch_size=1,
        gradient_accumulation_steps=8, # Simulation d'un batch de 8
        learning_rate=2e-4,
        warmup_ratio=0.03,
        logging_steps=1, # effectuer des logs a chaque etape
        eval_strategy="steps", # Enable evaluation
        eval_steps=50, # evaluer chaque 50 etapes
        save_strategy="epoch",
        report_to="none",
        optim="paged_adamw_32bit", # Optimiseur plus stable pour le 4-bit
        lr_scheduler_type="cosine",
        max_length=1024,
        fp16=False,# desactive fp16
        bf16=True, # active bf16

    )

    # 8) trainer
    trainer = SFTTrainer(
        model=model,
        args=sft_args,
        train_dataset=train_ds,
        eval_dataset=eval_ds,
        processing_class=tokenizer,
    )

    print("Début de l'entraînement...")
    trainer.train()

    # 9) Save
    trainer.model.save_pretrained(OUT_DIR)
    tokenizer.save_pretrained(OUT_DIR)
    print(f"\n✅ Terminé. Adapters LoRA sauvegardés dans: {OUT_DIR}\n")

    return trainer

trainer = main()

# %%
# ============================
# 1. INSTALLATION DES DÉPENDANCES
# ============================
# !pip install -q flask flask-cors pyngrok transformers peft accelerate bitsandbytes
# !pip install -q -U transformers

print("✅ Dépendances installées")

# %%
from pyngrok import ngrok

NGROK_AUTH_TOKEN = "37IyH53nHUWl3ktKnElYAO1kIWL_44qpxXYHwXX4wH3J3Hub3"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

public_url = ngrok.connect(8000).public_url
print("🌍 URL publique:", public_url)
print("Test health:", public_url + "/health")
print("Endpoint:", public_url + "/cv/generate")

# %%
# ============================
# 2. CONFIGURATION
# ============================
import os

PATH_PROJET    = "/content/drive/MyDrive/projet_cv/projet-cv"
DOSSIER_CACHE  = os.path.join(PATH_PROJET, "cache")
BASE_MODEL_ID  = "microsoft/phi-3-mini-4k-instruct"
ADAPTER_DIR    = os.path.join(PATH_PROJET, "model/cv-lora")

print(f"Base model : {BASE_MODEL_ID}")
print(f"Adapter dir: {ADAPTER_DIR}")
print(f"Cache dir  : {DOSSIER_CACHE}")

# %%
# ============================
# 3. CHARGEMENT DU MODÈLE + LoRA
# ============================
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig, AutoConfig
from peft import PeftModel

# --- Tokenizer ---
tokenizer = AutoTokenizer.from_pretrained(
    BASE_MODEL_ID,
    cache_dir=DOSSIER_CACHE,
    trust_remote_code=True,
    use_fast=True,
)
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# --- Quantization 4-bit (économise la VRAM) ---
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_use_double_quant=True,
)

# --- Workaround RoPE scaling Phi-3 ---
config = AutoConfig.from_pretrained(
    BASE_MODEL_ID,
    cache_dir=DOSSIER_CACHE,
    trust_remote_code=True,
)
if hasattr(config, "rope_scaling") and isinstance(config.rope_scaling, dict):
    rope_type = config.rope_scaling.get("type")
    if rope_type is None or rope_type == "dynamic":
        print(f"⚠️  RoPE scaling '{rope_type}' surchargé à None pour éviter ValueError.")
        config.rope_scaling = None

# --- Chargement base model ---
base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_ID,
    config=config,
    cache_dir=DOSSIER_CACHE,
    device_map="auto",
    quantization_config=bnb_config,
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
    attn_implementation="eager",  # évite warnings flash-attn
)

# --- Chargement LoRA (sans merge pour économiser la mémoire) ---
model = PeftModel.from_pretrained(base_model, ADAPTER_DIR)
model.eval()
model.config.use_cache = False   # évite bugs DynamicCache Phi-3

print("✅ Modèle chargé avec succès (base + LoRA).")
print(f"   GPU disponible : {torch.cuda.is_available()}")

# %%
# ============================
# 4. SYSTEM PROMPT & HELPERS
# ============================
import json, re

SYSTEM_PROMPT = (
    "Tu es un assistant RH expert. Tu produis UNIQUEMENT un JSON valide qui respecte EXACTEMENT ce schéma "
    "(mêmes clés, mêmes niveaux) : "
    '{ "informations": { "prenom": "", "nom": "", "titre": "", "email": "", '
    '"telephone": "", "adresse": "", "liens": [] }, '
    '"resume": "", '
    '"competences": { "techniques": [], "outils": [], "soft_skills": [] }, '
    '"experience": [ { "company": "", "role": "", "date_debut": "", "date_fin": "", "taches": [] } ], '
    '"education": [ { "ecole": "", "diplome": "", "annee": "" } ], '
    '"projets": [], "langues": [] }. '
    "Règles : Tu reformules et enrichis 'resume' et 'taches' avec un style professionnel. "
    "Tu n'inventes PAS d'entreprises, de dates ou de diplômes. "
    "Si une information manque, mets null ou \"\". "
    "Il est INTERDIT de changer les noms de clés (pas de 'candidate', pas de 'summary'). "
    "Il est INTERDIT d'ajouter du texte hors JSON. "
    "Tu dois répondre UNIQUEMENT avec un JSON valide."
)


def extract_json(text: str) -> str:
    """Extrait le premier bloc JSON complet d'une chaîne de texte."""
    start = text.find("{")
    end   = text.rfind("}")
    if start == -1 or end == -1 or end <= start:
        raise ValueError("Aucun bloc JSON trouvé dans la sortie du modèle.")
    return text[start:end + 1].strip()


def generate_cv(user_text: str) -> dict:
    """
    Génère un CV structuré en JSON à partir d'une description textuelle.
    Décode uniquement les tokens générés (pas le prompt) pour éviter
    les caractères de contrôle qui cassent json.loads().
    """
    messages = [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": user_text},
    ]
    prompt = tokenizer.apply_chat_template(
        messages, tokenize=False, add_generation_prompt=True
    )
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    input_len = inputs["input_ids"].shape[-1]

    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=900,
            do_sample=True,
            temperature=0.5,
            top_p=0.9,
            repetition_penalty=1.12,
            pad_token_id=tokenizer.eos_token_id,
            use_cache=False,
        )

    # ✅ Décode UNIQUEMENT les tokens générés (corrige le bug 422)
    generated_tokens = out[0][input_len:]
    raw_text = tokenizer.decode(generated_tokens, skip_special_tokens=True).strip()

    json_str = extract_json(raw_text)
    return json.loads(json_str)


print("✅ System prompt et helpers prêts.")

# %%
# ============================
# 5. APPLICATION FLASK
# ============================
from flask import Flask, request, jsonify
from flask_cors import CORS

app = Flask(__name__)
CORS(app)   # autorise les requêtes cross-origin (utile en dev)


# ---------- Routes ----------

@app.route("/health", methods=["GET"])
def health():
    """Vérification de l'état du serveur."""
    return jsonify({
        "status": "ok",
        "gpu": torch.cuda.is_available(),
        "model": BASE_MODEL_ID,
        "adapter": ADAPTER_DIR,
    })


@app.route("/cv/generate", methods=["POST"])
def cv_generate():
    """
    Génère un CV structuré en JSON.

    Body JSON attendu :
        { "input": "Nom Prénom. Titre. Résumé: ... Email: ... Compétences: ..." }

    Réponse :
        JSON complet du CV ou { "error": "message" } avec code 422.
    """
    data = request.get_json(force=True, silent=True)

    if not data or "input" not in data:
        return jsonify({"error": "Le champ 'input' est requis."}), 400

    user_text = data["input"].strip()
    if not user_text:
        return jsonify({"error": "Le champ 'input' ne peut pas être vide."}), 400

    try:
        cv_json = generate_cv(user_text)
        return jsonify(cv_json), 200
    except ValueError as ve:
        return jsonify({"error": f"Extraction JSON échouée : {ve}"}), 422
    except Exception as e:
        return jsonify({"error": f"Erreur interne : {e}"}), 500


print("✅ Application Flask créée.")

# %%
# ============================
# 6. DÉMARRAGE DU SERVEUR FLASK
# ============================
import threading

PORT = 5000

def run_flask():
    # use_reloader=False obligatoire dans un thread (pas de double démarrage)
    app.run(host="0.0.0.0", port=PORT, use_reloader=False, debug=False)

flask_thread = threading.Thread(target=run_flask, daemon=True)
flask_thread.start()

import time; time.sleep(2)
print(f"✅ Flask démarré sur http://0.0.0.0:{PORT}")

# %%
# ============================
# 7. EXPOSITION PUBLIQUE AVEC NGROK
# ============================
from pyngrok import ngrok

# ⚠️  Remplace par ton propre token : https://dashboard.ngrok.com/get-started/37IyH53nHUWl3ktKnElYAO1kIWL_44qpxXYHwXX4wH3J3Hub3
NGROK_AUTH_TOKEN = "37IyH53nHUWl3ktKnElYAO1kIWL_44qpxXYHwXX4wH3J3Hub3"
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Ferme les tunnels existants avant d'en ouvrir un nouveau
ngrok.kill()

public_url = ngrok.connect(PORT).public_url
print("🌍 URL publique :", public_url)
print("   Health  :", public_url + "/health")
print("   Generate:", public_url + "/cv/generate")

# %%
# ============================
# 8. TEST DE L'API
# ============================
import requests, time, json

BASE = public_url.strip()

# --- Health check ---
print("=== Health Check ===")
r_health = requests.get(BASE + "/health", timeout=15)
print("Status :", r_health.status_code)
print("Body   :", r_health.json())

# --- Génération CV ---
print("\n=== Test Génération CV ===")
test_inputs = [
    "Patrick Yoba. Étudiant ingénieur data/IA. Résumé: recherche stage data science. "
    "Email: patrick.yoba@email.com. Compétences: Python, SQL, ML. "
    "École: 3iL Limoges (2024-).",

    "Inès Wagner. Maître-Nageur Sauveteur. Tel: 0467112233. Adresse: Montpellier. "
    "Exp: Piscine Municipale (2022-2024). Compétences: Secourisme, Aquagym. "
    "Diplôme: BPJEPS AAN (2021).",
]

for i, text in enumerate(test_inputs, 1):
    print(f"\n--- Test {i} ---")
    print("Input:", text[:80], "...")
    try:
        r = requests.post(
            BASE + "/cv/generate",
            json={"input": text},
            headers={"Content-Type": "application/json"},
            timeout=300,
        )
        print("Status:", r.status_code)
        if r.status_code == 200:
            cv = r.json()
            print("Nom   :", cv.get("informations", {}).get("nom", "N/A"))
            print("Titre :", cv.get("informations", {}).get("titre", "N/A"))
            print("Résumé:", str(cv.get("resume", ""))[:120])
            print("✅ CV généré avec succès")
        else:
            print("❌ Erreur:", r.json())
    except Exception as e:
        print("❌ Exception:", e)

# %%
import json

# Choose one of the test prompts from earlier
example_prompt = test_inputs[0]

print(f"Generating CV for: {example_prompt[:100]}...")

# Generate the CV
example_cv_json = generate_cv(example_prompt)

# Pretty-print the JSON for better readability
print(json.dumps(example_cv_json, indent=2, ensure_ascii=False))

# %%
# ============================
# 10. ENVOI D'UN FICHIER JSON À L'API & RÉCUPÉRATION DU RÉSULTAT
# ============================
# 📄 STRUCTURE DU FICHIER D'ENTRÉE ATTENDU (input_cv.json) :
# Un fichier JSON contenant une liste de candidats, chacun avec un champ "input" :
#
# [
#   { "id": "001", "input": "Marie Dupont. Développeuse Python. Email: m.dupont@mail.com. Exp: TechCorp (2021-2024)..." },
#   { "id": "002", "input": "Jean Martin. Chef de projet. Compétences: Agile, Jira, SQL..." }
# ]
#
# ▶ Place ce fichier dans ton Drive ou upload-le directement dans Colab.
# ============================

import requests
import json
import os
import time

BASE = public_url.strip()
ENDPOINT = BASE + "/cv/generate"

# -------------------------------------------------------
# 📁 PARAMÈTRES — modifie ces deux chemins selon ton cas
# -------------------------------------------------------
INPUT_FILE  = "/content/drive/MyDrive/projet_cv/projet-cv/input_cv.json"   # fichier JSON en entrée
OUTPUT_FILE = "/content/drive/MyDrive/projet_cv/projet-cv/output_cvs.json"  # fichier résultat en sortie
# -------------------------------------------------------

# --- Lecture du fichier d'entrée ---
print(f"📂 Lecture du fichier : {INPUT_FILE}")
with open(INPUT_FILE, "r", encoding="utf-8") as f:
    candidats = json.load(f)

print(f"   {len(candidats)} candidat(s) trouvé(s).\n")

results = []
errors  = []

for i, candidat in enumerate(candidats, 1):
    candidat_id  = candidat.get("id", f"candidat_{i}")
    user_text    = candidat.get("input", "").strip()

    print(f"[{i}/{len(candidats)}] Traitement : {candidat_id}")

    if not user_text:
        print(f"   ⚠️  Champ 'input' vide, candidat ignoré.")
        errors.append({"id": candidat_id, "error": "Champ 'input' vide."})
        continue

    try:
        response = requests.post(
            ENDPOINT,
            json={"input": user_text},
            headers={"Content-Type": "application/json"},
            timeout=300,   # 5 min max par candidat (génération IA)
        )

        if response.status_code == 200:
            cv_data = response.json()
            results.append({
                "id"    : candidat_id,
                "status": "success",
                "cv"    : cv_data,
            })
            nom   = cv_data.get("informations", {}).get("nom", "N/A")
            titre = cv_data.get("informations", {}).get("titre", "N/A")
            print(f"   ✅ Succès — {nom} | {titre}")

        else:
            detail = response.json().get("error", response.text)
            print(f"   ❌ Erreur API ({response.status_code}) : {detail}")
            errors.append({"id": candidat_id, "error": detail, "status_code": response.status_code})

    except requests.exceptions.Timeout:
        print(f"   ⏱️  Timeout — candidat {candidat_id} ignoré.")
        errors.append({"id": candidat_id, "error": "Timeout"})

    except Exception as e:
        print(f"   ❌ Exception : {e}")
        errors.append({"id": candidat_id, "error": str(e)})

    time.sleep(0.5)   # petite pause pour ne pas saturer l'API

# --- Sauvegarde du fichier de sortie ---
output = {
    "total"   : len(candidats),
    "success" : len(results),
    "errors"  : len(errors),
    "results" : results,
    "errors_detail": errors,
}

os.makedirs(os.path.dirname(OUTPUT_FILE), exist_ok=True)
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(output, f, ensure_ascii=False, indent=2)

print(f"\n{'='*50}")
print(f"✅ Traitement terminé !")
print(f"   Succès : {len(results)}/{len(candidats)}")
print(f"   Erreurs: {len(errors)}/{len(candidats)}")
print(f"   Résultat sauvegardé dans : {OUTPUT_FILE}")
print(f"{'='*50}")

# --- Aperçu du premier résultat ---
if results:
    print("\n📋 Aperçu du 1er CV généré :")
    first_cv = results[0]["cv"]
    infos = first_cv.get("informations", {})
    print(f"   Nom    : {infos.get('prenom', '')} {infos.get('nom', '')}")
    print(f"   Titre  : {infos.get('titre', 'N/A')}")
    print(f"   Email  : {infos.get('email', 'N/A')}")
    print(f"   Résumé : {str(first_cv.get('resume', ''))[:150]}...")
    competences = first_cv.get("competences", {})
    print(f"   Skills : {competences.get('techniques', [])[:4]}")

# %% [markdown]
# Nous avons par la suite récupéré le fichier output_cvs.json Voici son contenu
#
# output_cvs.json
#
#
# {
#   "total": 2,
#   "success": 2,
#   "errors": 0,
#   "results": [
#     {
#       "id": "001",
#       "status": "success",
#       "cv": {
#         "competences": {
#           "outils": [
#             "Python",
#             "Docker"
#           ],
#           "soft_skills": [],
#           "techniques": [
#             "Python",
#             "SQL"
#           ]
#         },
#         "education": [
#           {
#             "annee": null,
#             "diplome": "Formation Ingénierie IA",
#             "ecole": "Sœurs de Lyon"
#           }
#         ],
#         "experece": [
#           {
#             "company": "TechCorp",
#             "date_debut": "2021",
#             "date_fin": "2024",
#             "role": "Ingénieure IA",
#             "taches": [
#               "Stagiaire Data Science"
#             ]
#           },
#           {
#             "company": "EDF Marseille",
#             "date_debut": "2021",
#             "date_fin": "2024",
#             "role": "Analyste Machine Learning",
#             "taches": [
#               "Projet Intelligence Artificielle"
#             ]
#           }
#         ],
#         "informations": {
#           "adresse": "Marseille, France",
#           "email": "m.dupont@mail.com",
#           "liens": [],
#           "nom": "Dupont",
#           "prenom": "Marie",
#           "telephone": null,
#           "titre": "Ingénieure IA"
#         },
#         "langues": [
#           "Français",
#           "Anglais"
#         ],
#         "projets": [
#           {
#             "annee": null,
#             "description": null,
#             "nom": "Agent Inteluitif AI"
#           },
#           {
#             "annee": null,
#             "description": null,
#             "nom": "Modèle ML Développement"
#           }
#         ],
#         "resume": "Spécialiste du développement intelligent automatique sur chalbes modernes."
#       }
#     },
#     {
#       "id": "002",
#       "status": "success",
#       "cv": {
#         "competences": {
#           "outils": [
#             "POWER BI",
#             "EXCEL",
#             "TAbleau"
#           ],
#           "soft_skills": [
#             "Intégration",
#             "Autonomie"
#           ],
#           "techniques": [
#             "Nettoyage de données",
#             "Création de dashboards"
#           ]
#         },
#         "education": [
#           {
#             "annee": "2019",
#             "diplome": "Licence Infoamtique",
#             "ecole": "Paris Dauphine"
#           },
#           {
#             "annee": "2024",
#             "diplome": "Diplôme Ingénieur ETDIV",
#             "ecole": "Institut Mines et Accompagnement"
#           }
#         ],
#         "expérience": [],
#         "informations": {
#           "adresse": null,
#           "email": null,
#           "liens": [],
#           "nom": "Martin",
#           "prenom": "Jean",
#           "telephone": null,
#           "titre": "Étudiant Data Analyst"
#         },
#         "langues": [
#           "Français",
#           "Espagnol"
#         ],
#         "projets": [],
#         "resume": "Étudiant motivé à la recherche d'une alternance dans le secteur des informations."
#       }
#     }
#   ],
#   "errors_detail": []
# }

# %% [markdown]
# Les résultats du Fine-Tuning (LoRA) sur Phi-3 Mini démontrent une excellente capacité du modèle à structurer l'information. L'identification des entités et leur classification dans le schéma JSON cible sont précises, validant ainsi l'efficacité de l'apprentissage sur la tâche d'extraction. Bien que nous notions des phénomènes d'hallucinations sur des noms propres (écoles, entreprises) et quelques instabilités syntaxiques sur les clés JSON, l'objectif principal est atteint : le modèle enrichit qualitativement les résumés de CV tout en respectant la segmentation attendue.
